# %%
import random

l = ['rock', 'scissor', 'paper']

while True:
    ucount=0
    Ccount=0
    uc = int(input('''
Game Start...
1.Yes
2.NO|Exit
   '''))
    
    if uc == 1:
        for i in range(1,6):
            userinput = int(input('''
1.rock
2.scissor
3.paper
'''))
            if userinput == 1:
                userchoice = "rock"
            elif userinput == 2:
                userchoice = "scissor"
            elif userinput == 3:
                userchoice = "paper"
            Cchoice = random.choice(l)
            
            if userchoice == Cchoice:
                print("user value ", userchoice)
                print("computer value ", Cchoice)
                print("Game draw")
                ucount = ucount+1
                ccount = Ccount+1
            elif (userchoice == "rock" and Cchoice == "scissor") or (userchoice == "scissor" and Cchoice == "paper") or (userchoice == "paper" and Cchoice == "rock"):
                print("user value ", userchoice)
                print("computer value ", Cchoice)
                print("You win")
                ucount = ucount+1
            else:
                print("user value ", userchoice)
                print("computer value ", Cchoice)
                print("Computer win")
                Ccount = Ccount+1
                
        if ucount == Ccount:
            print("Final Game Draw")
            print("User final score :", ucount)
            print("Computer final score : ", Ccount)
        elif ucount>Ccount:
            print("User final score :", ucount)
            print("Computer final score : ", Ccount)
            print("Fianlly User win the game")
        else:
            print("Finally computer win the game")
            print("User final score :", ucount)
            print("Computer final score : ", Ccount)
                
    else:
        break
# Out:
# Game Start...
# 1.Yes
# 2.NO|Exit
#    1
#
# 1.rock
# 2.scissor
# 3.paper
# 2
# user value  scissor
# computer value  scissor
# Game draw
#
# 1.rock
# 2.scissor
# 3.paper
# 3
# user value  paper
# computer value  scissor
# Computer win
#
# 1.rock
# 2.scissor
# 3.paper
# 2
# user value  scissor
# computer value  paper
# You win
#
# 1.rock
# 2.scissor
# 3.paper
# 1
# user value  rock
# computer value  rock
# Game draw
#
# 1.rock
# 2.scissor
# 3.paper
# 3
# user value  paper
# computer value  scissor
# Computer win
# User final score : 3
# Computer final score :  2
# Fianlly User win the game
#
# Game Start...
# 1.Yes
# 2.NO|Exit
#    2
